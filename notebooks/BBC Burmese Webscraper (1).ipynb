# %% [markdown]
# # BBC Burmese Webscraper (1): Scraping Headers and Dates of One Page
# by <a href="https://www.linkedin.com/in/la-wun-nannda-b047681b5/">`La Wun Nannda`</a>

# %% [markdown]
# ## Initial Setup

# %%
# import libraries
from bs4 import BeautifulSoup # this module helps in web scrapping
import requests  # this module helps us to download a web page
import pandas as pd

# %%
# define BBC URL
static_url = "https://www.bbc.com/burmese/topics/c9wpm0en9jdt"

# %%
# get html content from URL
response = requests.get(static_url)
print(response.content)
# Out:
# b'<!doctype html><html lang="my" class="no-js" dir="ltr"><head><title data-react-helmet="true">\xe1\x80\x80\xe1\x80\xaf\xe1\x80\x94\xe1\x80\xba\xe1\x80\x9e\xe1\x80\xbd\xe1\x80\x9a\xe1\x80\xba\xe1\x80\x85\xe1\x80\xae\xe1\x80\xb8\xe1\x80\x95\xe1\x80\xbd\xe1\x80\xac\xe1\x80\xb8 - BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac</title><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="robots" content="noodp, noydir, max-image-preview:large"/><meta data-react-helmet="true" name="theme-color" content="#B80000"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta data-react-helmet="true" name="apple-mobile-web-app-title" content="BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" name="application-name" content="BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" name="description" content=""/><meta data-react-helmet="true" property="fb:app_id" content="1609039196070050"/><meta data-react-helmet="true" name="facebook-domain-verification" content="mydfaj4vz8t5psneihy4nm6ff52fac"/><meta data-react-helmet="true" name="mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" name="msapplication-TileColor" content="#B80000"/><meta data-react-helmet="true" name="msapplication-TileImage" content="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-144x144.png"/><meta data-react-helmet="true" property="og:description" content=""/><meta data-react-helmet="true" property="og:image" content="https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png"/><meta data-react-helmet="true" property="og:image:alt" content="BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" property="og:locale" content="my-MM"/><meta data-react-helmet="true" property="og:site_name" content="BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" property="og:title" content="\xe1\x80\x80\xe1\x80\xaf\xe1\x80\x94\xe1\x80\xba\xe1\x80\x9e\xe1\x80\xbd\xe1\x80\x9a\xe1\x80\xba\xe1\x80\x85\xe1\x80\xae\xe1\x80\xb8\xe1\x80\x95\xe1\x80\xbd\xe1\x80\xac\xe1\x80\xb8 - BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="og:url" content="https://www.bbc.com/burmese/topics/c9wpm0en9jdt"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="twitter:creator" content="@bbcburmese"/><meta data-react-helmet="true" name="twitter:description" content=""/><meta data-react-helmet="true" name="twitter:image:alt" content="BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" name="twitter:image:src" content="https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png"/><meta data-react-helmet="true" name="twitter:site" content="@bbcburmese"/><meta data-react-helmet="true" name="twitter:title" content="\xe1\x80\x80\xe1\x80\xaf\xe1\x80\x94\xe1\x80\xba\xe1\x80\x9e\xe1\x80\xbd\xe1\x80\x9a\xe1\x80\xba\xe1\x80\x85\xe1\x80\xae\xe1\x80\xb8\xe1\x80\x95\xe1\x80\xbd\xe1\x80\xac\xe1\x80\xb8 - BBC News \xe1\x80\x99\xe1\x80\xbc\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xac"/><meta data-react-helmet="true" http-equiv="onion-location" content="https://www.bbcweb3hytmzhn5d532owbu6oqadra5z3ar726vq5kgwwn6aucdccrad.onion/burmese/topics/c9wpm0en9jdt"/><link data-react-helmet="true" rel="manifest" href="/burmese/manifest.json"/><link data-react-helmet="true" rel="canonical" href="https://www.bbc.com/burmese/topics/c9wpm0en9jdt"/><link data-react-helmet="true" re ...

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.content, 'html5lib')

# %%
# check the title to validate
print(soup.title)
# Out:
# <title data-react-helmet="true">ကုန်သွယ်စီးပွား - BBC News မြန်မာ</title>

# %%
# check the whole soup
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="my"><head><title data-react-helmet="true">ကုန်သွယ်စီးပွား - BBC News မြန်မာ</title><meta content="IE=edge" data-react-helmet="true" http-equiv="X-UA-Compatible"/><meta charset="utf-8" data-react-helmet="true"/><meta content="noodp, noydir, max-image-preview:large" data-react-helmet="true" name="robots"/><meta content="#B80000" data-react-helmet="true" name="theme-color"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" data-react-helmet="true" name="viewport"/><meta content="BBC News မြန်မာ" data-react-helmet="true" name="apple-mobile-web-app-title"/><meta content="BBC News မြန်မာ" data-react-helmet="true" name="application-name"/><meta content="" data-react-helmet="true" name="description"/><meta content="1609039196070050" data-react-helmet="true" property="fb:app_id"/><meta content="mydfaj4vz8t5psneihy4nm6ff52fac" data-react-helmet="true" name="facebook-domain-verification"/><meta content="yes" data-react-helmet="true" name="mobile-web-app-capable"/><meta content="#B80000" data-react-helmet="true" name="msapplication-TileColor"/><meta content="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-144x144.png" data-react-helmet="true" name="msapplication-TileImage"/><meta content="" data-react-helmet="true" property="og:description"/><meta content="https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png" data-react-helmet="true" property="og:image"/><meta content="BBC News မြန်မာ" data-react-helmet="true" property="og:image:alt"/><meta content="my-MM" data-react-helmet="true" property="og:locale"/><meta content="BBC News မြန်မာ" data-react-helmet="true" property="og:site_name"/><meta content="ကုန်သွယ်စီးပွား - BBC News မြန်မာ" data-react-helmet="true" property="og:title"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="https://www.bbc.com/burmese/topics/c9wpm0en9jdt" data-react-helmet="true" property="og:url"/><meta content="summary_large_image" data-react-helmet="true" name="twitter:card"/><meta content="@bbcburmese" data-react-helmet="true" name="twitter:creator"/><meta content="" data-react-helmet="true" name="twitter:description"/><meta content="BBC News မြန်မာ" data-react-helmet="true" name="twitter:image:alt"/><meta content="https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png" data-react-helmet="true" name="twitter:image:src"/><meta content="@bbcburmese" data-react-helmet="true" name="twitter:site"/><meta content="ကုန်သွယ်စီးပွား - BBC News မြန်မာ" data-react-helmet="true" name="twitter:title"/><meta content="https://www.bbcweb3hytmzhn5d532owbu6oqadra5z3ar726vq5kgwwn6aucdccrad.onion/burmese/topics/c9wpm0en9jdt" data-react-helmet="true" http-equiv="onion-location"/><link data-react-helmet="true" href="/burmese/manifest.json" rel="manifest"/><link data-react-helmet="true" href="https://www.bbc.com/burmese/topics/c9wpm0en9jdt" rel="canonical"/><link data-react-helmet="true" href="https://www.bbc.com/burmese/topics/c9wpm0en9jdt" hreflang="my" rel="alternate"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-192x192.png" rel="apple-touch-icon"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-96x96.png" rel="apple-touch-icon" sizes="96x96"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-128x128.png" rel="apple-touch-icon" sizes="128x128"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link data-react-helmet="true" href="https://static.files.bbci.co.uk/ws/simorgh-assets/public/burmese/images/icons/ ...
#   				if ("FileReader" in window && "Promise" in window && "fetch" in window) {
#   				const fontsForStorage = [{"fontFamily":"Padauk","fontWeight":400,"fontStyle":"normal","src":"https://ws-downloads.files.bbci.co.uk/fonts/Padauk/v2.8/normal.woff2","fontDisplay":"swap","baseUrl":"https://ws-downloads.files.bbci.co.uk/fonts/Padauk/v2.8/"},{"fontFamily":"Padauk","fontWeight":700,"fontStyle":"normal","src":"https://ws-downloads.files.bbci.co.uk/fonts/Padauk/v2.8/bold.woff2","fontDisplay":"swap","baseUrl":"https://ws-downloads.files.bbci.co.uk/fonts/Padauk/v2.8/"}];
#                 const getFont = (location) => {
#                 	return new Promise(function (resolve, reject) {
# 						fetch(location).then(function (res) {
# 						  return res.blob()
# 						}).then(function (blob) {
# 						  if (blob && blob.constructor.name === 'Blob') {
# 							  var reader = new FileReader()
# 							  reader.addEventListener('load', function () {
# 								resolve(this.result)
# 							  })
# 							  reader.readAsDataURL(blob)
# 						  }
# 						}).catch(reject)
# 					  })
#                 };
#                 const createStyleAndAttach = (styleInnerText) => {
#                     const head = document.head || document.getElementsByTagName('head')[0];
# 					const fontStylePlaceholder = document.createElement('style');
# 					fontStylePlaceholder.innerHTML = styleInnerText;
# 					head.appendChild(fontStylePlaceholder);
#                 };
#                 const retrieveAndStoreFont = (font, storageKey, shouldAttachStyle) => {
#                 	const fontLocation = font.src ? font.src : 'https://static.files.bbci.co.uk/fonts/reith/'+ font.version + (font.subsets ? '/subsets' : '') + '/' + font.name + '.woff2';
#                     window.addEventListener("load", (e) => {
#                     getFont(fontLocation).then((fontContents) => {
#                     	const forStorage = { base64Contents: fontContents, fontFamily: font.fontFamily, fontWeight: font.fontWeight, fontVersion: font.version };
#                     	localStorage.setItem(storageKey, JSON.stringify(forStorage));
#                     	if (shouldAttachStyle) {
#                     		const styleInnerText = '@font-face{font-family: "' + font.fontFamily + '"; font-weight: ' + font.fontWeight + ';src:url("' + fontContents + '") format("woff2");font-display: swap;}';
#                     		createStyleAndAttach(styleInnerText);
#                 		}
#                     });
#                     });
#                 };
#                 fontsForStorage.forEach(font => {
#                     const storageKey = 'font-' + font.name;
#                     let fontContents = localStorage.getItem(storageKey);
#
#                     if (!fontContents) {
#                         retrieveAndStoreFont(font, storageKey, true);
#                     }
#                     else {
#                     	const { base64Contents, fontFamily, fontWeight, fontVersion } = JSON.parse(fontContents);
#                     	const styleInnerText = '@font-face{font-family: "' + fontFamily + '"; font-weight: ' + fontWeight + '; src:url("' + base64Contents + '") format("woff2");font-display: swap;}';
#                 		createStyleAndAttach(styleInnerText);
#                 		if (fontVersion !== font.version) {
#                 			retrieveAndStoreFont(font, storageKey, false);
#                 		}
#                     }
#                 });
#                 }
#                 let wrappedPageTimeStart = new Date();
#                 let wrappedYear = wrappedPageTimeStart.getFullYear();
#                 let wrappedMonth = wrappedPageTimeStart.getMonth() + 1;
#                 let wrappedStorageKey = 'ws_bbc_wrapped';
#                 let wrappedContents = {};
#                 wrappedContents[wrappedYear] = {
#                     'byMonth': {},
#                     'pageTypeCounts': {},
#                     'serviceCounts': {},
#                     'topicCounts': {},
#                     'duration': 0,
#                     'wordCount': 0,
#                 };
#                 wrappedContents[wrappedYear].byMonth[wrappedMonth] = 0;
#                 let saveWrapped = () => {
#                     localStorage.setItem(wrappedStorageKey, JSON.stringify(wrappedContents));
#                 }
#                 let wrappedLocalStorageContents = localStorage.getItem(wrappedStorageKey);
#                 if (wrappedLocalStorageContents) {
#                     const wrappedLocalStorageContentsParsed = JSON.parse(wrappedLocalStorageContents);
#                     if (wrappedLocalStorageContentsParsed.hasOwnProperty(wrappedYear)) {
#                         wrappedContents[wrappedYear] = wrappedLocalStorageContentsParsed[wrappedYear] || wrappedContents[wrappedYear];
#                         wrappedContents[wrappedYear].byMonth[wrappedMonth] = wrappedLocalStorageContentsParsed[wrappedYear].byMonth[wrappedMonth] || 0;
#                     }
#                 }
#                 let wrappedContentsShortcut = wrappedContents[wrappedYear];
#                 let wrappedTopics = undefined;
#                 if (wrappedTopics) {
#                     wrappedTopics.forEach(({ topicName }) => {
#                         wrappedContentsShortcut.topicCounts[topicName] = wrappedContentsShortcut.topicCounts[topicName] ? wrappedContentsShortcut.topicCounts[topicName] + 1 : 1;
#                     });
#                 }
#                 document.onvisibilitychange = () => {
#                   if (document.visibilityState === "hidden") {
#                     const wrappedTimeNow = new Date();
#                     const wrappedDifference = wrappedTimeNow - wrappedPageTimeStart;
#                     wrappedContentsShortcut.duration = wrappedContentsShortcut.duration ? wrappedContentsShortcut.duration + wrappedDifference : wrappedDifference;
#                     saveWrapped();
#                   }
#                   else {
#                     wrappedPageTimeStart = new Date();
#                   }
#                 };
#                 wrappedContentsShortcut.wordCount = wrappedContentsShortcut.wordCount + 0;
#                 wrappedContentsShortcut.serviceCounts.burmese = wrappedContentsShortcut.serviceCounts.burmese ? wrappedContentsShortcut.serviceCounts.burmese + 1 : 1;
#                 wrappedContentsShortcut.pageTypeCounts.Topic = wrappedContentsShortcut.pageTypeCounts.Topic ? wrappedContentsShortcut.pageTypeCounts.Topic + 1 : 1;
#                 wrappedContentsShortcut.byMonth[wrappedMonth] = wrappedContentsShortcut.byMonth[wrappedMonth] ? wrappedContentsShortcut.byMonth[wrappedMonth] + 1 : 1;
#                 wrappedContents[wrappedYear] = wrappedContentsShortcut;
#     </script><script data-react-helmet="true" type="application/ld+json">{"@context":"http://schema.org","@graph":[{"@type":"CollectionPage","url":"https://www.bbc.com/burmese/topics/c9wpm0en9jdt","publisher":{"@type":"NewsMediaOrganization","name":"BBC News မြန်မာ","publishingPrinciples":"https://www.bbc.com/burmese/institutional-51387206","logo":{"@type":"ImageObject","width":1024,"height":576,"url":"https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png"}},"thumbnailUrl":"https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png","image":{"@type":"ImageObject","width":1024,"height":576,"url":"https://news.files.bbci.co.uk/ws/img/logos/og/burmese.png"},"mainEntityOfPage":{"@type":"WebPage","@id":"https://www.bbc.com/burmese/topics/c9wpm0en9jdt","name":"ကုန်သွယ်စီးပွား"},"headline":"ကုန်သွယ်စီးပွား","inLanguage":{"@type":"Language","name":"Burmese","alternateName":"my"}},{"itemListElement":[{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c2j3j7gdpgxo","position":1},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/ce58epzze2ko","position":2},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cydv54l96p8o","position":3},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c51y9451245o","position":4},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/crgl26y9w32o","position":5},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cxw2x1me8jeo","position":6},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c8vdgm579jyo","position":7},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c51y89571nqo","position":8},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cprq2nynx5eo","position":9},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cldyze660nzo","position":10},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c3ge10e0e9eo","position":11},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/ced3231qk2eo","position":12},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cxe2v4r1x2xo","position":13},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cl4yjx5lj0ro","position":14},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c9r375ql0n2o","position":15},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cek9gz871emo","position":16},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/ck5g2rwyg7yo","position":17},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cg64y70d99no","position":18},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c4nngxl8832o","position":19},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c800epnde1no","position":20},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c144kw9ww90o","position":21},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cljje5l7787o","position":22},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/cx9940e9vzyo","position":23},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.bbc.com/burmese/articles/c3gg3jz80x8o","position":24}],"@type":"ItemList","name":"BBC News မြန်မာ","numberOfItems":24}]}</script><style data-emotion-css="q8cnfh 16ubpog 1cc1evb 1d ...
#         to right,
#         rgba(255, 255, 255, 0) 0%,
#         rgba(255, 255, 255, 1) 100%
#       );}@media (min-width: 25rem){.bbc-mcfoow:after{width:6rem;}}}.bbc-11krpir{list-style-type:none;padding:0;margin:0;position:relative;}@media (min-width: 37.5rem){.bbc-11krpir{overflow:hidden;}}.bbc-zakhp8{display:inline-block;position:relative;z-index:2;-webkit-margin-end:0.75rem;margin-inline-end:0.75rem;}@media (max-width: 37.4375rem){.bbc-zakhp8:last-child{margin-right:3rem;}}@media (min-width: 37.5rem){.bbc-zakhp8::after{content:'';position:absolute;bottom:-1px;width:80rem;border-bottom:0.0625rem solid #E6E8EA;z-index:-1;}}.bbc-qh9e61{font-size:0.9375rem;line-height:1.5625rem;font-family:Padauk,Arial,Verdana,Geneva,Helvetica,sans-serif;font-weight:400;font-style:normal;color:#141414;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:inline-block;padding:0.75rem 0.25rem;outline:none;}@media (min-width: 20rem) and (max-width: 37.4375rem){.bbc-qh9e61{font-size:1rem;line-height:1.75rem;}}@media (min-width: 37.5rem){.bbc-qh9e61{font-size:1rem;line-height:1.875rem;}}@media (max-width: 37.4375rem){.bbc-qh9e61{padding:0.75rem 0.5rem;}}.bbc-qh9e61:hover::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;}.bbc-qh9e61:focus::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;top:0;border:0.1875rem solid #000000;}.bbc-qh9e61:focus-visible::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;top:0;border:0.1875rem solid #000000;}.bbc-w9q58u{font-size:0.9375rem;line-height:1.5625rem;font-family:Padauk,Arial,Verdana,Geneva,Helvetica,sans-serif;font-weight:400;font-style:normal;color:#141414;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:inline-block;padding:0.75rem 0.25rem;outline:none;}@media (min-width: 20rem) and (max-width: 37.4375rem){.bbc-w9q58u{font-size:1rem;line-height:1.75rem;}}@media (min-width: 37.5rem){.bbc-w9q58u{font-size:1rem;line-height:1.875rem;}}@media (max-width: 37.4375rem){.bbc-w9q58u{padding:0.75rem 0.5rem;}}.bbc-w9q58u:hover::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;border-bottom:0.3125rem solid #B80000;}.bbc-w9q58u:focus::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;top:0;border:0.1875rem solid #000000;}.bbc-w9q58u:focus-visible::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;top:0;border:0.1875rem solid #000000;}.bbc-aqw31p::after{content:'';position:absolute;left:0;right:0;bottom:0;border-bottom:0.25rem solid #B80000;}.bbc-1x40ipt{background-color:#FFFFFF;clear:both;overflow:hidden;height:0;-webkit-transition:all 0.2s ease-out;transition:all 0.2s ease-out;transition-timing-function:cubic-bezier(0, 0, 0.58, 1);visibility:hidden;}@media (min-width: 37.5rem){.bbc-1x40ipt{display:none;visibility:hidden;}}@media (prefers-reduced-motion: reduce){.bbc-1x40ipt{-webkit-transition:none;transition:none;}}.bbc-dz10ac{list-style-type:none;margin:0;padding:0 0.5rem;border-bottom:0.0625rem solid #E6E8EA;}.bbc-89wdkq{padding:0.75rem 0;border-bottom:0.0625rem solid #E6E8EA;}.bbc-89wdkq:last-child{padding-bottom:0.25rem;border:0;}.bbc-5pgein{font-size:0.9375rem;line-height:1.5625rem;font-family:Padauk,Arial,Verdana,Geneva,Helvetica,sans-serif;font-weight:400;font-style:normal;color:#141414;-webkit-text-decoration:none;text-decoration:none;padding:0.75rem 0;display:inline-block;}@media (min-width: 20rem) and (max-width: 37.4375rem){.bbc-5pgein{font-size:1rem;line-height:1.75rem;}}@media (min-width: 37.5rem){.bbc-5pgein{font-size:1rem;line-height:1.875rem;}}.bbc-5pgein:hover,.bbc-5pgein:focus{-webkit-text-decoration:underline;text-decoration:underline;text-decoration-color:#B80000;}.bbc-12xbtlj{border-left:0.25rem solid #B80000;padding-left:0.5rem;}.bbc-q944gg{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;}.bbc-18yqr0l{margin:0 0.5rem;}@media (min-width: 25r ...

# %% [markdown]
# ## Data Formatting

# %%
# our headers are within the anchor elements
news_anchors_soup = soup.find_all('a')
news_anchors_soup
# Out:
# [<a aria-labelledby="BrandLink-topPage" class="focusIndicatorRemove bbc-1x4x290 e10yv9r11" href="/burmese" id="topPage"><svg aria-hidden="true" class="bbc-1jefi8v e10yv9r10" focusable="false" height="32" id="brandSvgHeader" viewBox="140 140 1261 145" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd
#  <a class="focusIndicatorRemove bbc-qh9e61 e11sm0on3" href="/burmese/topics/cj7v92le02qt">ဗီဒီယိုများ</a>,
#  <a aria-labelledby="dropdownNavigation-ပင်မစာမျက်နှာ" class="bbc-5pgein ebniykg2" href="/burmese"><span id="dropdownNavigation-ပင်မစာမျက်နှာ">ပင်မစာမျက်နှာ</span></a>,
#  <a aria-labelledby="dropdownNavigation-မြန်မာ့ရေးရာ" class="bbc-5pgein ebniykg2" href="/burmese/topics/c404v08p1wxt"><span id="dropdownNavigation-မြန်မာ့ရေးရာ">မြန်မာ့ရေးရာ</span></a>,
#  <a aria-labelledby="dropdownNavigation-နိုင်ငံတကာ" class="bbc-5pgein ebniykg2" href="/burmese/topics/cnlv9j1z93wt"><span id="dropdownNavigation-နိုင်ငံတကာ">နိုင်ငံတကာ</span></a>,
#  <a aria-labelledby="dropdownNavigation-ဆောင်းပါး" class="bbc-5pgein ebniykg2" href="/burmese/topics/cl3rq8rkqgxt"><span id="dropdownNavigation-ဆောင်းပါး">ဆောင်းပါး</span></a>,
#  <a aria-labelledby="dropdownNavigation-အင်တာဗျူး" class="bbc-5pgein ebniykg2" href="/burmese/topics/cdg42x4kek0t"><span id="dropdownNavigation-အင်တာဗျူး">အင်တာဗျူး</span></a>,
#  <a aria-labelledby="dropdownNavigation-ကုန်သွယ်စီးပွား" class="bbc-5pgein ebniykg2" href="/burmese/topics/c9wpm0en9jdt"><span class="bbc-12xbtlj ebniykg1" dir="ltr" id="dropdownNavigation-ကုန်သွယ်စီးပွား" role="text"><span class="bbc-m04vo2">လက်ရှိကြည့်နေသော စာမျက်နှာ, </span>ကုန်သွယ်စီးပွား</span></a>,
#  <a aria-labelledby="dropdownNavigation-ဗီဒီယိုများ" class="bbc-5pgein ebniykg2" href="/burmese/topics/cj7v92le02qt"><span id="dropdownNavigation-ဗီဒီယိုများ">ဗီဒီယိုများ</span></a>,
#  <a aria-labelledby="c2j3j7gdpgxo" class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c2j3j7gdpgxo"><span id="c2j3j7gdpgxo" role="text"><span class="bbc-m04vo2" data-testid="visually-hidden-text">ဗီဒီယို, </span>တကောင်း နီကယ် စက်ရုံ ကို ပြည်သူ့ကာကွယ်ရေး လုံခြုံရေးပေး<span class="bbc-m04vo2">ကြာမြင့်ချိန်, 3,43</span></span></a>,
#  <a aria-labelledby="ce58epzze2ko" class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/ce58epzze2ko"><span id="ce58epzze2ko" role="text"><span class="bbc-m04vo2" data-testid="visually-hidden-text">ဗီဒီယို, </span>မြို့ကြီးတွေမှာ စက်သုံးဆီ ဝယ်ဖို့ ခက်ခဲ<span class="bbc-m04vo2">ကြာမြင့်ချိန်, 2,19</span></span></a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cydv54l96p8o"> ဗီယက်နမ်ခေါင်းဆောင် ငုယင်ဖူချောင်း အသက် ၈ဝ မှာ ကွယ်လွန်</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c51y9451245o">‘ကျွန်တော်လက်ထဲ ဘာလက်နက်မှမရှိဘူး’- ပစ်သတ်ခံခဲ့ရတဲ့ ဘင်္ဂလားဒေ့ရှ်ဆန္ဒပြကျောင်းသား</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/crgl26y9w32o">ဘန်ကောက် ဟိုတယ်ထဲ သေဆုံးသူ ၆ ဦးရဲ့သွေးထဲမှာ ဆိုင်ယာနိုက် တွေ့</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/
</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c800epnde1no"> ဆန်တန်းစီဝယ်ယူနေရသလို ဆန်ဆိုင်ပိုင်ရှင်တချို့ ဖမ်းဆီးခံရ</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c144kw9ww90o">စစ်ဆေးဖမ်းဆီးမှုတွေကြောင့် ဆန်စျေးနှုန်းကျလာနိုင်လား</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cljje5l7787o">ရုရှားပိုင်ဆိုင်မှုထဲကနေ ဒေါ်လာသန်းပေါင်း ငါးသောင်း ယူကရိန်းကို ချေးငှားဖို့ G7 သဘောတူ </a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cx9940e9vzyo">ကန်ပိုက်တီ(ကံပိုင်တည်) - KIA ထိန်းချုပ်လာတဲ့တရုတ်နယ်စပ်ကုန်သွယ်ရေးစခန်းလမ်းပိုင်း</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c3gg3jz80x8o">ယူကရိန်းစစ်ပွဲ အပစ်ရပ်ရေး ကန့်သတ်ချက်တွေ သမ္မတပူတင် ချပြ</a>,
#  <a aria-current="page" class="focusIndicatorOutlineBlack bbc-gtjcdn" href="?page=1">1</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=2">2</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=3">3</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=4">4</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=5">5</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=6">6</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=7">7</a>,
#  <a class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=29">29</a>,
#  <a aria-labelledby="pagination-next-page" class="focusIndicatorOutlineBlack bbc-1spja2a" href="?page=2"><span id="pagination-next-page"><span class="bbc-m04vo2">ရှေ့သို့သွားရန်</span><svg aria-hidden="true" focusable="false" height="12" viewBox="0 0 32 32" width="12"><path d="M21.6 14.3L5.5 31h6.4l14.6-15L11.9 1H5.5l16.1 16.7v-3.4z"></path></svg></span></a>,
#  <a aria-labelledby="BrandLink-footer" class="focusIndicatorRemove bbc-1x4x290 e10yv9r11" href="/burmese" id="footer"><svg aria-hidden="true" class="bbc-1jefi8v e10yv9r10" focusable="false" height="32" id="brandSvgFooter" viewBox="140 140 1261 145" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" stroke="#000" stroke-width=".335" style="stroke:#fff"><path d="M1231.328 254.024c0 7.828-1.641 13.446-4.88 16.694-3.107 3.108-8.82 4.682-16.984 4.682h-5.028c-8.163 0-13.876-1.576-16.984-4.682-3.239-3.248-4.88-8.864-4.88-16.694v-82.607c0-7.96 1.641-13.642 4.872-16.884 1.455-1.396 3.27-2.469 5.387-3.19 2.223-.746 4.072-1.183 5.505-1.3 1.562-.131 3.579-.199 5.999-.199h5.335c2.408 0 4.425.068 5.995.2 1.433.116 3.258.568 5.423 1.346 2.083.742 3.845 1.856 5.242 3.32 1.39 1.388 2.59 3.143 3.565 5.218 1.247 2.643 1.433 3.878 1.433 4.378v1.529h8.095v-1.53c0-2.046-.641-4.559-1.905-7.465a25.668 25.668 0 00-5.146-7.712c-4.814-4.89-11.758-7.37-20.636-7.37h-9.476c-8.993 0-16 2.44-20.82 7.252-4.62 4.623-6
.908h-1.53c-.849 0-1.926-.245-3.197-.73-1.367-.536-2.839-1.305-4.37-2.282-1.415-.907-2.634-2.284-3.626-4.09-.99-1.797-1.49-3.84-1.49-6.07 0-3.808 1.213-6.803 3.712-9.158 2.527-2.374 5.3-3.528 8.479-3.528 4.132 0 7.19 1.756 9.35 5.37l.914 1.528 5.155-4.266-.524-1.08c-1.244-2.569-3.266-4.651-6.01-6.19zM1392.525 198.076c-4.811-4.886-10.623-7.364-17.276-7.364-3.256 0-6.5.634-9.64 1.886-3.042 1.217-5.607 2.554-7.624 3.974-1.233.87-2.838 2.089-4.779 3.629-1.685-3.465-4.124-6.477-7.253-8.958l-1.271-1.008-4.64 6.646.94.904c4.67 4.485 7.035 9.891 7.035 16.068 0 2.02-.258 3.99-.765 5.87-4.494-3.732-9.895-5.624-16.068-5.624-5.971 0-11.334 1.96-15 ...
#  <a class="focusIndicatorInvert bbc-1pq84hw" href="https://www.bbc.com/burmese/institutional-51387206">ဘီဘီစီကို ဘာကြောင့် ယုံကြည်နိုင်သလဲ။</a>,
#  <a class="focusIndicatorInvert bbc-1pq84hw" href="https://www.bbc.com/burmese/institutional-37574842">အသုံးပြုရန်စည်းမျဉ်း</a>,
#  <a class="focusIndicatorInvert bbc-1pq84hw" href="https://www.bbc.com/burmese/institutional-37577521">ကိုယ်ရေးအချက်အလက်လုံခြုံမှု မူဝါဒ</a>,
#  <a class="focusIndicatorInvert bbc-1pq84hw" href="https://www.bbc.com/usingthebbc/cookies/">ကွတ်ကီး</a>,
#  <a class="focusIndicatorInvert bbc-1pq84hw" href="https://www.bbc.co.uk/burmese/send/u50853269">ဘီဘီစီကို ဆက်သွယ်ရန်</a>,
#  <a class="focusIndicatorInvert bbc-rjoq8e" href="#" lang="en-GB">Do not share or sell my info</a>,
#  <a class="focusIndicatorInvert bbc-1c05ye8" href="https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-links">ပြင်ပဝက်ဆိုက်များကို လင့် ထည့်ပေးခြင်းနှင့် ပတ်သက်သော ဘီဘီစီလုပ်ထုံးလုပ်နည်းကို ဖတ်ရန်။</a>]

# %%
# filter news header with class
news_headers_soup = soup.find_all("a", {"class":"focusIndicatorDisplayBlock"})
news_headers_soup
# Out:
# [<a aria-labelledby="c2j3j7gdpgxo" class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c2j3j7gdpgxo"><span id="c2j3j7gdpgxo" role="text"><span class="bbc-m04vo2" data-testid="visually-hidden-text">ဗီဒီယို, </span>တကောင်း နီကယ် စက်ရုံ ကို ပြည်သူ့ကာကွယ်ရေး လုံခြုံရေးပေး<span class="bbc-m04vo2">ကြာမြင့်ချိန်, 3,43</span></span></a>,
#  <a aria-labelledby="ce58epzze2ko" class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/ce58epzze2ko"><span id="ce58epzze2ko" role="text"><span class="bbc-m04vo2" data-testid="visually-hidden-text">ဗီဒီယို, </span>မြို့ကြီးတွေမှာ စက်သုံးဆီ ဝယ်ဖို့ ခက်ခဲ<span class="bbc-m04vo2">ကြာမြင့်ချိန်, 2,19</span></span></a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cydv54l96p8o"> ဗီယက်နမ်ခေါင်းဆောင် ငုယင်ဖူချောင်း အသက် ၈ဝ မှာ ကွယ်လွန်</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c51y9451245o">‘ကျွန်တော်လက်ထဲ ဘာလက်နက်မှမရှိဘူး’- ပစ်သတ်ခံခဲ့ရတဲ့ ဘင်္ဂလားဒေ့ရှ်ဆန္ဒပြကျောင်းသား</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles
</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c4nngxl8832o">ထရမ့်မဲဆွယ်စည်းရုံးရေးအတွက် ဒေါ်လာ သန်း ၅၀ လှူခဲ့တဲ့ ဘီလျံနာ ဘယ်သူလဲ</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c800epnde1no"> ဆန်တန်းစီဝယ်ယူနေရသလို ဆန်ဆိုင်ပိုင်ရှင်တချို့ ဖမ်းဆီးခံရ</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c144kw9ww90o">စစ်ဆေးဖမ်းဆီးမှုတွေကြောင့် ဆန်စျေးနှုန်းကျလာနိုင်လား</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cljje5l7787o">ရုရှားပိုင်ဆိုင်မှုထဲကနေ ဒေါ်လာသန်းပေါင်း ငါးသောင်း ယူကရိန်းကို ချေးငှားဖို့ G7 သဘောတူ </a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/cx9940e9vzyo">ကန်ပိုက်တီ(ကံပိုင်တည်) - KIA ထိန်းချုပ်လာတဲ့တရုတ်နယ်စပ်ကုန်သွယ်ရေးစခန်းလမ်းပိုင်း</a>,
#  <a class="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0" href="https://www.bbc.com/burmese/articles/c3gg3jz80x8o">ယူကရိန်းစစ်ပွဲ အပစ်ရပ်ရေး ကန့်သတ်ချက်တွေ သမ္မတပူတင် ချပြ</a>]

# %%
# get date and time
datetime_soup = soup.find_all("time", {"class":"promo-timestamp"})
datetime_soup
# Out:
# [<time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-08-02">လွန်ခဲ့သော ၅၂ မိနစ် က</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-30">၃၀ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-19">၁၉ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-18">၁၈ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-17">၁၇ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-13">၁၃ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-11">၁၁ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-07">၇ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-06">၆ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-05">၅ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-04">၄ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-03">၃ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-03">၃ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-01">၁ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-07-01">၁ ဇူလိုင် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-30">၃၀ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-29">၂၉ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-29">၂၉ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-26">၂၆ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-25">၂၅ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-23">၂၃ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-16">၁၆ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-15">၁၅ ဇွန် ၂၀၂၄</time>,
#  <time class="promo-timestamp bbc-11pkra2 e1mklfmt0" datetime="2024-06-14">၁၄ ဇွန် ၂၀၂၄</time>]

# %%
# gather information

# lists to store information
news_headers = []
datetime = []

if len(news_headers_soup)==len(datetime_soup): # if the lengths are the same, start adding them to the lists
    for i in range(len(news_headers_soup)): # get index

        # list 1 for news headers
        try: # for news headers without video tag # video tagged ones will cause errors
            news_headers.append(news_headers_soup[i].string.strip()) # convert 'BeautifulSoup string' to 'Python string' # add content to list 1
        except AttributeError: # # for news headers with video tag
            # list() is used to convert 'BeautifulSoup tag' object to 'list' to enable iteration 
            news_headers.append(list(news_headers_soup[i].span)[1].strip()) # convert 'BeautifulSoup string' to 'Python string' # add content to list 1

        # list 2 for date and time
        datetime.append(datetime_soup[i].string.strip()) # convert 'BeautifulSoup string' to 'Python string' # add content to list 2
        
    if (len(news_headers)==len(news_headers_soup)) & (len(datetime)==len(datetime_soup)): # if everything is added to two lists
        print("Done")
# Out:
# Done

# %%
news_headers
# Out:
# ['တကောင်း နီကယ် စက်ရုံ ကို ပြည်သူ့ကာကွယ်ရေး လုံခြုံရေးပေး',
#  'မြို့ကြီးတွေမှာ စက်သုံးဆီ ဝယ်ဖို့ ခက်ခဲ',
#  'ဗီယက်နမ်ခေါင်းဆောင် ငုယင်ဖူချောင်း အသက် ၈ဝ မှာ ကွယ်လွန်',
#  '‘ကျွန်တော်လက်ထဲ ဘာလက်နက်မှမရှိဘူး’- ပစ်သတ်ခံခဲ့ရတဲ့ ဘင်္ဂလားဒေ့ရှ်ဆန္ဒပြကျောင်းသား',
#  'ဘန်ကောက် ဟိုတယ်ထဲ သေဆုံးသူ ၆ ဦးရဲ့သွေးထဲမှာ ဆိုင်ယာနိုက် တွေ့',
#  'ထိုင်းဗီဇာမလိုဘဲ ပြည်တွင်းဝင်ခွင့် နိုင်ငံ ၃၀ ကျော်ကို တိုးပေး',
#  'ရိုးမရဲ့ ဘီလျံနာသူဌေးကြီး ဆာ့ချ်ပန်းကို စစ်ကောင်စီက စစ်ဆေးနေ',
#  'ဘီလျံနာ သူဌေးတွေရဲ့ ငပလီ သောက',
#  'ဇူလိုင် ၆ ရက် နိုင်ငံတဝန်းသတင်းအနှစ်ချုပ် - ဒုတိယဗိုလ်ချုပ်မှူးကြီးစိုးဝင်း တရုတ်ကို သွားရောက်',
#  'ဗြိတိသျှ ဝန်ကြီးချုပ်သစ် ဆာ ကီယာစတာမာ ဘယ်လိုလူလဲ',
#  'ပြည်ပနေ တရုတ်တွေ လိမ်လည်မှုတွေနဲ့ ရင်ဆိုင်နေရ',
#  'စဉ့်ကူးမြို့နယ်ထဲမှာ စစ်ကောင်စီ လေကြောင်းက ပစ်ခတ်နေ',
#  'ထိပ်တန်း ဘဏ်တွေ အပါအဝင် ဘဏ် ၇ ခု အရေးယူခံရ',
#  'ပြင်သစ်ရွေးကောက်ပွဲ လက်ယာစွန်းတွေ ဦးဆောင်',
#  'ကုန်သည်ကို ဖမ်းရုံနဲ့ ဆန်ဈေးကို ထိန်းနိုင်မလား',
#  'စစ်မှုထမ်း - ထိုင်းမှာ အလုပ်အကိုင်သိန်းချီရှိနေပေမဲ့ မြန်မာလူငယ်တွေ အလုပ်လက်မဲ့ဖြစ်နေတာ ဘာကြောင့်လဲ',
#  'ဇွန် ၂၉ ရက် နိုင်ငံတဝန်းသတင်းအနှစ်ချုပ် - ဗိုလ်ချုပ်မှုးကြီးမင်းအောင်လှိုင် နဲ့ စစ်ဗိုလ်ချုပ်တချို့ကို ဖမ်းဝရမ်းထုတ်ဖို့ အာဂျင်တီးနားဥပဒေအရာရှိ လျှောက်ထား',
#  'အားသွင်းဖို့ အချိန် ၅ မိနစ်သာလိုတဲ့ လျှပ်စစ်ကားဘက်ထရီ',
#  'ထရမ့်မဲဆွယ်စည်းရုံးရေးအတွက် ဒေါ်လာ သန်း ၅၀ လှူခဲ့တဲ့ ဘီလျံနာ ဘယ်သူလဲ',
#  'ဆန်တန်းစီဝယ်ယူနေရသလို ဆန်ဆိုင်ပိုင်ရှင်တချို့ ဖမ်းဆီးခံရ',
#  'စစ်ဆေးဖမ်းဆီးမှုတွေကြောင့် ဆန်စျေးနှုန်းကျလာနိုင်လား',
